# %% [markdown]
# ### Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Reading the Algerian forest fire dataset

# %%
df=pd.read_csv('Algerian_forest_fires.csv',header=1)

# %%
# Checking first 5 rows 
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
# Checking last 5 rows
df.tail()
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes  Region
# 239  6.5      fire       1
# 240  0.0  not fire       1
# 241  0.2  not fire       1
# 242  0.7  not fire       1
# 243  0.5  not fire       1

# %%
df.shape
# Out:
# (246, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df.describe()
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   246   245   245         245  245  245   245   245  245  245  245  245
# unique   33     5     2          20   63   19    40   174  167  199  107  175
# top      01    07  2012          35   64   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
#
#         FWI Classes
# count   245       244
# unique  128         9
# top     0.4   fire
# freq     12       131

# %%
df.iloc[121:125,:]
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 121                             30     09  2012           25   78   14    1.4
# 122  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 123                            day  month  year  Temperature   RH   Ws  Rain
# 124                             01     06  2012           32   71   12    0.7
#
#      FFMC  DMC   DC  ISI  BUI  FWI    Classes
# 121    45  1.9  7.5  0.2  2.4  0.1  not fire
# 122   NaN  NaN  NaN  NaN  NaN  NaN          NaN
# 123  FFMC  DMC   DC  ISI  BUI  FWI    Classes
# 124  57.1  2.5  8.2  0.6  2.8  0.2  not fire

# %%
df.drop([122,123],inplace=True)

# %%
df.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)

# %%
df.loc[:122,"Region"]=0
df.loc[122:,"Region"]=1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
# removing the not needed space between column names to avoid confusion
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df.dtypes
# Out:
# day             object
# month           object
# year            object
# Temperature     object
# RH              object
# Ws              object
# Rain            object
# FFMC            object
# DMC             object
# DC              object
# ISI             object
# BUI             object
# FWI             object
# Classes         object
# Region         float64
# dtype: object

# %%
df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws',"Region"]]=df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws',"Region"]].astype(int)

# %%
df.Classes.unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'not fire     ', 'not fire    '], dtype=object)

# %%
# removing the not needed space between data to avoid confusion
df.Classes=df.Classes.str.strip()
df.Classes.unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %%
df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']]=df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype('float')

# %%
df.dtypes
# Out:
# day              int32
# month            int32
# year             int32
# Temperature      int32
# RH               int32
# Ws               int32
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# Region           int32
# dtype: object

# %%
# Dropping the year column as all the data are from same year
df1=df.drop(['year'],axis=1)

# %%
df1.describe().T
# Out:
#              count       mean        std   min    25%   50%    75%    max
# day          243.0  15.761317   8.842552   1.0   8.00  16.0  23.00   31.0
# month        243.0   7.502058   1.114793   6.0   7.00   8.0   8.00    9.0
# Temperature  243.0  32.152263   3.628039  22.0  30.00  32.0  35.00   42.0
# RH           243.0  62.041152  14.828160  21.0  52.50  63.0  73.50   90.0
# Ws           243.0  15.493827   2.811385   6.0  14.00  15.0  17.00   29.0
# Rain         243.0   0.762963   2.003207   0.0   0.00   0.0   0.50   16.8
# FFMC         243.0  77.842387  14.349641  28.6  71.85  83.3  88.30   96.0
# DMC          243.0  14.680658  12.393040   0.7   5.80  11.3  20.80   65.9
# DC           243.0  49.430864  47.665606   6.9  12.35  33.1  69.10  220.4
# ISI          243.0   4.742387   4.154234   0.0   1.40   3.5   7.25   19.0
# BUI          243.0  16.690535  14.228421   1.1   6.00  12.4  22.65   68.0
# FWI          243.0   7.035391   7.440568   0.0   0.70   4.2  11.45   31.1
# ...

# %%
# Converting categorical value of fire and fire into numeric value
df1['Classes']=np.where(df1['Classes']=='not fire ',0,1)

# %%
df1.head()
# Out:
#    day  month  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    1      6           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    2      6           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2    3      6           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    4      6           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4    5      6           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5
#
#    Classes  Region
# 0        1       0
# 1        1       0
# 2        1       0
# 3        1       0
# 4        1       0

# %%
df1.corr()
# Out:
#                   day     month  Temperature        RH        Ws      Rain  \
# day          1.000000 -0.000369     0.097227 -0.076034  0.047812 -0.112523
# month       -0.000369  1.000000    -0.056781 -0.041252 -0.039880  0.034822
# Temperature  0.097227 -0.056781     1.000000 -0.651400 -0.284510 -0.326492
# RH          -0.076034 -0.041252    -0.651400  1.000000  0.244048  0.222356
# Ws           0.047812 -0.039880    -0.284510  0.244048  1.000000  0.171506
# Rain        -0.112523  0.034822    -0.326492  0.222356  0.171506  1.000000
# FFMC         0.224956  0.017030     0.676568 -0.644873 -0.166548 -0.543906
# DMC          0.491514  0.067943     0.485687 -0.408519 -0.000721 -0.288773
# DC           0.527952  0.126511     0.376284 -0.226941  0.079135 -0.298023
# ISI          0.180543  0.065608     0.603871 -0.686667  0.008532 -0.347484
# BUI          0.517117  0.085073     0.459789 -0.353841  0.031438 -0.299852
# ...

# %%
sns.pairplot(df1)
plt.title("Pairplot of Dataset")
# Out:
# Text(0.5, 1.0, 'Pairplot of Dataset')

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(df1.corr(),annot=True)
plt.title("Heatmap of dataset")
# Out:
# Text(0.5, 1.0, 'Heatmap of dataset')

# %%
plt.scatter(df1['FFMC'],df1['Temperature'])
plt.xlabel("FFMC")
plt.ylabel("Temperature")
plt.title("Scatter plot of DMC and temperature")
# Out:
# Text(0.5, 1.0, 'Scatter plot of DMC and temperature')

# %%
sns.regplot(x='FFMC',y='Temperature',data=df1)
plt.title("Regression plot of FFMC and temperature")
# Out:
# Text(0.5, 1.0, 'Regression plot of FFMC and temperature')

# %%
plt.scatter(df1['FWI'],df1['Temperature'])
plt.xlabel("FWI")
plt.ylabel("Temperature")
plt.title("Scatter plot of DMC and temperature")
# Out:
# Text(0.5, 1.0, 'Scatter plot of DMC and temperature')

# %%
sns.regplot(x='FWI',y='Temperature',data=df1)
plt.title("Regression plot of FWI and temperature")
# Out:
# Text(0.5, 1.0, 'Regression plot of FWI and temperature')

# %%
plt.scatter(df1['DMC'],df1['Temperature'])
plt.xlabel("DMC")
plt.ylabel("Temperature")
plt.title("Scatter plot of DMC and Temperature")
# Out:
# Text(0.5, 1.0, 'Scatter plot of DMC and Temperature')

# %%
sns.regplot(x='DMC',y='Temperature',data=df1)
plt.title("Regression plot of DMC and temperature")
# Out:
# Text(0.5, 1.0, 'Regression plot of DMC and temperature')

# %%
df1.hist(figsize=(20,14),color='r')
# Out:
# array([[<AxesSubplot:title={'center':'day'}>,
#         <AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'Temperature'}>,
#         <AxesSubplot:title={'center':'RH'}>],
#        [<AxesSubplot:title={'center':'Ws'}>,
#         <AxesSubplot:title={'center':'Rain'}>,
#         <AxesSubplot:title={'center':'FFMC'}>,
#         <AxesSubplot:title={'center':'DMC'}>],
#        [<AxesSubplot:title={'center':'DC'}>,
#         <AxesSubplot:title={'center':'ISI'}>,
#         <AxesSubplot:title={'center':'BUI'}>,
#         <AxesSubplot:title={'center':'FWI'}>],
#        [<AxesSubplot:title={'center':'Classes'}>,
#         <AxesSubplot:title={'center':'Region'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
percentage=df.Classes.value_counts(normalize=True)*100
percentage
# Out:
# fire        56.378601
# not fire    43.621399
# Name: Classes, dtype: float64

# %%
classes_labels=['Fire','Not Fire']
plt.figure(figsize=(8,6))
plt.pie(percentage,labels=classes_labels,autopct="%1.1f%%")
plt.title("Pie Chart of Classes",fontsize=15)
plt.show()

# %%
sns.boxplot(df1['Temperature'])
plt.title("Box plot of Temperature")
# Out:
# c:\Users\adars\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Box plot of Temperature')

# %%
sns.boxplot(df['FWI'],color='orange')
plt.title("Box plot of FWI")
# Out:
# c:\Users\adars\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Box plot of FWI')
